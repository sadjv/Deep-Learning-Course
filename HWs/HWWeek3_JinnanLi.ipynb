# %% [markdown]
# # Week 3 Programming Assignment
#
# Remark:
#
# Please upload your solutions of this assignment to Canvas with a file named "Programming_Assignment_3 _yourname.ipynb" before 11:59pm June 6.

# %% [markdown]
# =================================================================================================================

# %% [markdown]
# ### **Problem 1 (6 pt).** Use stochastic gradient descent method to train MNIST with 1 hidden layer neural network model to achieve at least 97% test accuracy. Print the results with the following format:
#
#    "Epoch: i, Training accuracy: $a_i$, Test accuracy: $b_i$"
#
# where $i=1,2,3,...$ means the $i$-th epoch,  $a_i$ and $b_i$ are the training accuracy and test accuracy computed at the end of $i$-th epoch.

# %%
# write your code for solving probelm 1 in this cell
import torch
import torch.nn as nn 
import torch.optim as optim
import torchvision
import torch.nn.functional as F

# Define a 1-hidden layer neural network.
class model(nn.Module): 
    def __init__(self,input_size,hidden_size,num_classes):
        super().__init__() 
        self.fc1 = nn.Linear(input_size, hidden_size) 
        self.fc2 = nn.Linear(hidden_size, num_classes) 
    def forward(self, x): 
        x = x.reshape(x.size(0), input_size) # you can reshape the iamges here. 
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x



input_size = 784
hidden_size = 500
num_classes = 10

minibatch_size = 128
num_epochs = 20
lr = 0.1

# Step 1: Define a model
my_model =model(input_size,hidden_size, num_classes)

# Step 2: Define a loss function and training algorithm
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(my_model.parameters(), lr=lr)


# Step 3: load dataset

MNIST_transform = torchvision.transforms.Compose([torchvision.transforms.ToTensor()])

trainset = torchvision.datasets.MNIST(root='./data', train= True, download=True, transform=MNIST_transform)


trainloader = torch.utils.data.DataLoader(trainset, batch_size=minibatch_size)

testset = torchvision.datasets.MNIST(root='./data', train= False, download=True, transform=MNIST_transform)


testloader = torch.utils.data.DataLoader(testset, batch_size=1) 

#Step 4: Train the NNs
# One epoch is when an entire dataset is passed through the neural network only once.
print('a')
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(trainloader):
        
        #images = images.reshape(images.size(0), 28*28) # move this reshape to model class

        # Forward pass to get the loss
        outputs = my_model(images) 
        loss = criterion(outputs, labels)
        
        # Backward and compute the gradient
        optimizer.zero_grad()
        loss.backward()  #backpropragation
        optimizer.step() #update the weights/parameters
        
    # Training accuracy
    correct = 0
    total = 0
    for i, (images, labels) in enumerate(trainloader):
        #images = images.reshape(images.size(0), 28*28) # move this reshape to model class
        outputs = my_model(images)
        p_max, predicted = torch.max(outputs, 1) 
        total += labels.size(0)
        correct += (predicted == labels).sum()
    training_accuracy = float(correct)/total

    
    # Test accuracy
    correct = 0
    total = 0
    for i, (images, labels) in enumerate(testloader):
        #images = images.reshape(images.size(0), 28*28) # move this reshape to model class
        outputs = my_model(images)
        p_max, predicted = torch.max(outputs, 1) 
        total += labels.size(0)
        correct += (predicted == labels).sum()
    test_accuracy = float(correct)/total
        
    print('Epoch: {}, the training accuracy: {}, the test accuracy: {}' .format(epoch+1,training_accuracy,test_accuracy))
# Out:
# a
# Epoch: 1, the training accuracy: 0.9043166666666667, the test accuracy: 0.9106
# Epoch: 2, the training accuracy: 0.92705, the test accuracy: 0.9303
# Epoch: 3, the training accuracy: 0.9405833333333333, the test accuracy: 0.9403
# Epoch: 4, the training accuracy: 0.9496, the test accuracy: 0.9477
# Epoch: 5, the training accuracy: 0.9569166666666666, the test accuracy: 0.9547
# Epoch: 6, the training accuracy: 0.9623, the test accuracy: 0.9593
# Epoch: 7, the training accuracy: 0.9665, the test accuracy: 0.9625
# Epoch: 8, the training accuracy: 0.97025, the test accuracy: 0.9658
# Epoch: 9, the training accuracy: 0.9732333333333333, the test accuracy: 0.9691
# Epoch: 10, the training accuracy: 0.9755, the test accuracy: 0.9714
# Epoch: 11, the training accuracy: 0.9773333333333334, the test accuracy: 0.9722
# Epoch: 12, the training accuracy: 0.9788, the test accuracy: 0.9731
# Epoch: 13, the training accuracy: 0.9806166666666667, the test accuracy: 0.9746
# Epoch: 14, the training accuracy: 0.9819833333333333, the test accuracy: 0.9756
# Epoch: 15, the training accuracy: 0.9831833333333333, the test accuracy: 0.9769
# Epoch: 16, the training accuracy: 0.9842333333333333, the test accuracy: 0.977
# Epoch: 17, the training accuracy: 0.9851166666666666, the test accuracy: 0.9777
# Epoch: 18, the training accuracy: 0.98625, the test accuracy: 0.9776
# Epoch: 19, the training accuracy: 0.98695, the test accuracy: 0.9781
# Epoch: 20, the training accuracy: 0.9878833333333333, the test accuracy: 0.9788

# %% [markdown]
# =================================================================================================================

# %% [markdown]
# ### **Problem 2 (4 pts).** Use stochastic gradient descent method to train CIFAR-10 with
# * (1) logistic regression model to achieve at least 25% test accuracy
# * (2) 2-hidden layers neural network model to achieve at least 50% test accuracy
#
# Print the results with the following format:
#
# * For logistic regression model, print:
#
#     "Logistic Regression Model, Epoch: i, Training accuracy: $a_i$, Test accuracy: $b_i$"
#
#
# * For 2-hidden layers neural network model, print:
#
#     "DNN Model, Epoch: i, Training accuracy: $a_i$, Test accuracy: $b_i$"
#
#
# where $i=1,2,3,...$ means the $i$-th epoch,  $a_i$ and $b_i$ are the training accuracy and test accuracy computed at the end of $i$-th epoch.
#
# Hint:
#
# (1) The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images.
#
# (2) The input_size should be $3072=3*32*32$, where 3 is the number of channels (RGB image), $32*32$ is the size of every image.
#
# (3) For the 2-hidden layers neural network model, consider to use $W^1\in \mathbb{R}^{3072\times3072}$ for the 1st-hidden layer, $W^2 \in \mathbb{R}^{500\times 3072}$ for the 2nd-hidden layer and $W^3 \in \mathbb{R}^{10\times 500}$ for the output layer.

# %%
# write your code for solving probelm 2 in this cell
# write your code for solving probelm 1 in this cell
import torch
import torch.nn as nn 
import torch.optim as optim
import torchvision
import torch.nn.functional as F

# Define a 1-hidden layer neural network.
class models(nn.Module): 
    def __init__(self,input_size,hidden_size1,hidden_size2,num_classes):
        super().__init__() 
        self.fc1 = nn.Linear(input_size, hidden_size1) 
        self.fc2 = nn.Linear(hidden_size1, hidden_size2)
        self.fc3 = nn.Linear(hidden_size2, num_classes) 
    def forward(self, x): 
        x = x.reshape(x.size(0), input_size) # you can reshape the iamges here. 
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x
    
input_size = 3072
hidden_size1 = 3072
hidden_size2 = 500
num_classes = 10

minibatch_size = 15
num_epochs = 20
lr = 0.1

# Step 1: Define a model
my_models =models(input_size, hidden_size1, hidden_size2, num_classes)

# Step 2: Define a loss function and training algorithm
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(my_models.parameters(), lr=lr)

# You can load CIFAR-10 dataset as follows:
CIFAR10_transform = torchvision.transforms.Compose([torchvision.transforms.ToTensor()])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=CIFAR10_transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=minibatch_size, shuffle=True)

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=CIFAR10_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=1, shuffle=False)

#Step 4: Train the NNs
# One epoch is when an entire dataset is passed through the neural network only once.
print('a')
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(trainloader):
        
        #images = images.reshape(images.size(0), 28*28) # move this reshape to model class

        # Forward pass to get the loss
        outputs = my_models(images) 
        loss = criterion(outputs, labels)
        
        # Backward and compute the gradient
        optimizer.zero_grad()
        loss.backward()  #backpropragation
        optimizer.step() #update the weights/parameters
        
    # Training accuracy
    correct = 0
    total = 0
    for i, (images, labels) in enumerate(trainloader):
        #images = images.reshape(images.size(0), 28*28) # move this reshape to model class
        outputs = my_models(images)
        p_max, predicted = torch.max(outputs, 1) 
        total += labels.size(0)
        correct += (predicted == labels).sum()
    training_accuracy = float(correct)/total

    
    # Test accuracy
    correct = 0
    total = 0
    for i, (images, labels) in enumerate(testloader):
        #images = images.reshape(images.size(0), 28*28) # move this reshape to model class
        outputs = my_models(images)
        p_max, predicted = torch.max(outputs, 1) 
        total += labels.size(0)
        correct += (predicted == labels).sum()
    test_accuracy = float(correct)/total
        
    print('DNN Model, Epoch: {}, the training accuracy: {}, the test accuracy: {}' .format(epoch+1,training_accuracy,test_accuracy))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# a
# DNN Model, Epoch: 1, the training accuracy: 0.30748, the test accuracy: 0.3045
# DNN Model, Epoch: 2, the training accuracy: 0.42376, the test accuracy: 0.4224
# DNN Model, Epoch: 3, the training accuracy: 0.4472, the test accuracy: 0.4396
# DNN Model, Epoch: 4, the training accuracy: 0.4219, the test accuracy: 0.4109
# DNN Model, Epoch: 5, the training accuracy: 0.4775, the test accuracy: 0.4567
# DNN Model, Epoch: 6, the training accuracy: 0.46608, the test accuracy: 0.4394
# DNN Model, Epoch: 7, the training accuracy: 0.51016, the test accuracy: 0.476
# DNN Model, Epoch: 8, the training accuracy: 0.52136, the test accuracy: 0.4754
# DNN Model, Epoch: 9, the training accuracy: 0.54458, the test accuracy: 0.4873
# DNN Model, Epoch: 10, the training accuracy: 0.53258, the test accuracy: 0.4683
# DNN Model, Epoch: 11, the training accuracy: 0.54602, the test accuracy: 0.4711
# DNN Model, Epoch: 12, the training accuracy: 0.58242, the test accuracy: 0.4959
# DNN Model, Epoch: 13, the training accuracy: 0.59294, the test accuracy: 0.4871
# DNN Model, Epoch: 14, the training accuracy: 0.58352, the test accuracy: 0.4889
# DNN Model, Epoch: 15, the training accuracy: 0.62848, the test accuracy: 0.5121

# %%
# write your code for solving probelm 1 in this cell
# Hint: you can tune the number of epoches, learning rate and mini-batch size.
import torch
import torch.nn as nn # Import functions from torch.nn
import torchvision
import matplotlib.pyplot as plt
import torch.optim as optim

def modelss(input_size,num_classes):
    return nn.Linear(input_size,num_classes)

input_size = 3072
num_classes = 10


my_model2 =modelss(input_size, num_classes)

criterion = nn.CrossEntropyLoss()

optimizer = optim.SGD(my_model2.parameters(), lr=0.1)

CIFAR10_transform = torchvision.transforms.Compose([torchvision.transforms.ToTensor()])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=CIFAR10_transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=128, shuffle=True)

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=CIFAR10_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=1, shuffle=False)


num_epochs = 20
# One epoch is when an entire dataset is passed through the neural network only once.
for epoch in range(num_epochs):
    num_train = 0
    total_tr = 0
    for i, (images, labels) in enumerate(trainloader):
        # You can check the size of image before images.reshape, which is [batch_size,1,28,28]
        #print(images.size()) 
        # Reshape MNIST images to (batch_size, input_size)
        images = images.reshape(images.size(0), 3072)
        
        # Forward pass to get the loss
        outputs = my_model2(images) # the outputs of xW^{T}+b
        loss = criterion(outputs, labels)
        
        # Backward and compute the gradient
        optimizer.zero_grad()
        loss.backward()  #backpropragation
        optimizer.step()
        
        p_max1, predicted1 = torch.max(outputs, 1) 
        total_tr += labels.size(0) # you can also use labels.size()[0], see the test  below
        num_train += (predicted1 == labels).sum()
        
    num_test = 0
    total_te = 0
    for i, (images, labels) in enumerate(testloader):
        images = images.reshape(images.size(0), 3072)
        outputs = my_model2(images)
        
        p_max, predicted = torch.max(outputs, 1) 
        total_te += labels.size(0) # you can also use labels.size()[0], see the test  below
        num_test += (predicted == labels).sum()
        
    print('Logistic Regression Model, Epoch [{}], train accuracy: {}, test accuracy: {}' .format(epoch+1,float(num_train)/total_tr,float(num_test)/total_te))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Logistic Regression Model, Epoch [1], train accuracy: 0.19502, test accuracy: 0.197
# Logistic Regression Model, Epoch [2], train accuracy: 0.23038, test accuracy: 0.2341
# Logistic Regression Model, Epoch [3], train accuracy: 0.2414, test accuracy: 0.2687
# Logistic Regression Model, Epoch [4], train accuracy: 0.2473, test accuracy: 0.282
# Logistic Regression Model, Epoch [5], train accuracy: 0.25114, test accuracy: 0.2321
# Logistic Regression Model, Epoch [6], train accuracy: 0.25428, test accuracy: 0.201
# Logistic Regression Model, Epoch [7], train accuracy: 0.25924, test accuracy: 0.2464
# Logistic Regression Model, Epoch [8], train accuracy: 0.25802, test accuracy: 0.227
# Logistic Regression Model, Epoch [9], train accuracy: 0.25764, test accuracy: 0.3038
# Logistic Regression Model, Epoch [10], train accuracy: 0.2673, test accuracy: 0.1816
# Logistic Regression Model, Epoch [11], train accuracy: 0.26336, test accuracy: 0.2929
# Logistic Regression Model, Epoch [12], train accuracy: 0.27086, test accuracy: 0.2239
# Logistic Regression Model, Epoch [13], train accuracy: 0.2712, test accuracy: 0.2133
# Logistic Regression Model, Epoch [14], train accuracy: 0.26918, test accuracy: 0.2533
# Logistic Regression Model, Epoch [15], train accuracy: 0.27098, test accuracy: 0.2906
# Logistic Regression Model, Epoch [16], train accuracy: 0.27356, test accuracy: 0.2835
# Logistic Regression Model, Epoch [17], train accuracy: 0.27252, test accuracy: 0.2761
# Logistic Regression Model, Epoch [18], train accuracy: 0.2736, test accuracy: 0.1943
# Logistic Regression Model, Epoch [19], train accuracy: 0.2693, test accuracy: 0.2335
# Logistic Regression Model, Epoch [20], train accuracy: 0.27608, test accuracy: 0.2659

# %% [markdown]
# =================================================================================================================
